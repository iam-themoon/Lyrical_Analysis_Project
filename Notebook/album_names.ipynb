# %%
# install azapi 
# if using Google Colab, this will be necessary each time the notebook is reopened
# !pip install azapi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting azapi
#   Downloading azapi-3.0.8-py3-none-any.whl (20 kB)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from azapi) (0.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from azapi) (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->azapi) (4.6.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->azapi) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->azapi) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->azapi) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->azapi) (2022.5.18.1)
# Installing collected packages: azapi
# Successfully installed azapi-3.0.8

# %%
# import dependencies 
import azapi
from azapi import AZlyrics
import pprint
import pandas as pd

# %%
# read in csv and create dataframe
df = pd.read_csv('bestsellingsingles.csv')
df.head()
# Out:
#                               song          artist  released actual_sales  \
# 0                  White Christmas     Bing Crosby      1941           25
# 1          Candle in the Wind 1997      Elton John      1997         8.84
# 2                 We Are the World  USA for Africa      1985            8
# 3  Rudolph, the Red-Nosed Reindeer      Gene Autry      1949            7
# 4                       Paper Doll  Mills Brothers      1943            6
#
#   times_platinum
# 0             4×
# 1            11×
# 2             4×
# 3           None
# 4           None

# %%
# narrow df to only 'song' and 'artist' columns
song_artist = df[['song', 'artist']]
song_artist.head()
# Out:
#                               song          artist
# 0                  White Christmas     Bing Crosby
# 1          Candle in the Wind 1997      Elton John
# 2                 We Are the World  USA for Africa
# 3  Rudolph, the Red-Nosed Reindeer      Gene Autry
# 4                       Paper Doll  Mills Brothers

# %%
# create dictionary of song/artist key/value pairs
singles_dict = song_artist.set_index('song').to_dict()['artist']
singles_dict
# Out:
# {'(Everything I Do) I Do It for You': 'Bryan Adams',
#  '7 Years': 'Lukas Graham',
#  'A Thousand Years': 'Christina Perri',
#  'Airplanes': 'B.o.B featuring Hayley Williams',
#  'All About That Bass': 'Meghan Trainor',
#  'All I Want For Christmas Is You': 'Mariah Carey',
#  'All of Me': 'John Legend',
#  'Apologize': 'Timbaland featuring OneRepublic',
#  'Baby': 'Justin Bieber featuring Ludacris',
#  'Baby Shark': 'Pinkfong',
#  'Bad Blood': 'Taylor Swift featuring Kendrick Lamar',
#  'Bad Romance': 'Lady Gaga',
#  'Bang Bang': 'Jessie J, Ariana Grande and Nicki Minaj',
#  'Believer': 'Imagine Dragons',
#  'Better Now': 'Post Malone',
#  'Black Beatles': 'Rae Sremmurd featuring Gucci Mane',
#  'Black and Yellow': 'Wiz Khalifa',
#  'Blank Space': 'Taylor Swift',
#  'Blinding Lights': 'The Weeknd',
#  'Blurred Lines': 'Robin Thicke featuring T.I. and Pharrell Williams',
#  'Bodak Yellow': 'Cardi B',
#  'Body Like a Back Road': 'Sam Hunt',
#  'Bohemian Rhapsody': 'Queen',
#  'Boom Boom Pow': 'The Black Eyed Peas',
#  'Born This Way': 'Lady Gaga',
#  'Boyfriend': 'Justin Bieber',
#  'Broccoli': 'DRAM featuring Lil Yachty',
#  'California Gurls': 'Katy Perry featuring Snoop Dogg',
#  'Call Me Maybe': 'Carly Rae Jepsen',
#  "Can't Feel My Face": 'The Weeknd',
#  "Can't Hold Us": 'Macklemore & Ryan Lewis featuring Ray Dalton',
#  'Candle in the Wind 1997': 'Elton John',
#  'Chandelier': 'Sia',
#  'Cheap Thrills': 'Sia',
#  'Chicken Fried': 'Zac Brown Band',
#  'Closer': 'The Chainsmokers featuring Halsey',
#  'Congratulations': 'Post Malone ft. Quavo',
#  'Counting Stars': 'OneRepublic',
#  'Country Girl (Shake It for Me)': 'Luke Bryan',
#  'Cruise': 'Florida Georgia Line',
#  'Dardanella': 'Ben Selvin',
#  'Dark Horse': 'Katy Perry featuring Juicy J',
#  'Demons': 'Imagine Dragons',
#  'Despacito': 'Luis Fonsi and Daddy Yankee featuring Justin Bieber',
#  'Diamonds': 'Rihanna',
#  'Disturbia': 'Rihanna',
#  "Don't Let Me Down": 'The Chainsmokers featuring Daya',
#  'Down': 'Jay Sean featuring Lil Wayne',
#  'Drip Too Hard': 'Lil Baby featuring Gunna',
#  'E.T.': 'Katy Perry featuring Kanye West',
#  'Earned It': 'The Weeknd',
#  'Eye of the Tiger': 'Survivor',
#  'F*ck You/Forget You': 'Cee Lo Green',
#  'Fancy': 'Iggy Azalea featuring Charli XCX',
#  'Fefe': '6ix9ine featuring Nicki Minaj and Murda Beatz',
#  'Fireflies': 'Owl City',
#  'Firework': 'Katy Perry',
#  'Forever': 'Chris Brown',
#  'Fuck Love': 'XXXTentacion',
#  'Girls Like You': 'Maroon 5 featuring Cardi B',
#  'Give Me Everything': 'Pitbull featuring Afrojack, Nayer and Ne-Yo',
#  "God's Plan": 'Drake',
#  'Gold Digger': 'Kanye West featuring Jamie Foxx',
#  'Goosebumps': 'Travis Scott',
#  'Grenade': 'Bruno Mars',
#  'Happy': 'Pharrell Williams',
#  'Havana': 'Camila Cabello featuring Young Thug',
#  'Heartless': 'Kanye West',
#  'Heathens': 'Twenty One Pilots',
#  'Hello': 'Adele',
#  'Hey Jude': 'The Beatles',
#  'Hey, Soul Sister': 'Train',
#  "Hold On, We're Going Home": 'Drake featuring Majid Jordan',
#  'Hot n Cold': 'Katy Perry',
#  'Hotline Bling': 'Drake',
#  'Hound Dog" / "Don\'t Be Cruel': 'Elvis Presley',
#  'Humble': 'Kendrick Lamar',
#  'I Fall Apart': 'Post Malone',
#  'I Gotta Feeling': 'The Black Eyed Peas',
#  'I Heard It Through the Grapevine': 'Marvin Gaye',
#  'I Kissed a Girl': 'Katy Perry',
#  'I Knew You Were Trouble': 'Taylor Swift',
#  'I Like It': 'Cardi B, Bad Bunny and J Balvin',
#  'I Wanna Dance with Somebody (Who Loves Me)': 'Whitney Houston',
#  'I Will Always Love You': 'Whitney Houston',
#  "I Won't Give Up": 'Jason Mraz',
#  "I'm Not the Only One": 'Sam Smith',
#  "I'm Yours": 'Jason Mraz',
#  "I'm a Believer": 'the Monkees',
#  "I'm the One": 'DJ Khaled featuring Justin Bieber, Quavo, Chance the Rapper and Lil Wayne',
#  'If I Die Young': 'The Band Perry',
#  'Just Dance': "Lady Gaga featuring Colby O'Donis",
#  'Just the Way You Are': 'Bruno Mars',
#  'Last Friday Night (T.G.I.F.)': 'Katy Perry',
#  'Le Freak': 'Chic',
#  'Lean On': 'Major Lazer and DJ Snake featuring MØ',
#  'Let Her Go': 'Passenger',
#  'Let It Go': 'Idina Menzel',
#  'Let You Down': 'NF',
#  'Life Is Good': 'Future featuring Drake',
#  'Location': 'Khalid',
#  'Locked Out of Heaven': 'Bruno Mars',
#  'Look at Me Now': 'Chris Brown featuring Lil Wayne and Busta Rhymes',
#  'Lose Yourself': 'Eminem',
#  'Love Story': 'Taylor Swift',
#  'Love Yourself': 'Justin Bieber',
#  'Love the Way You Lie': 'Eminem featuring Rihanna',
#  'Low': 'Flo Rida featuring T-Pain',
#  'Lucid Dreams': 'Juice WRLD',
#  'Macarena': 'Los del Río',
#  'Mask Off': 'Future',
#  'Meant to Be': 'Bebe Rexha featuring Florida Georgia Line',
#  'Middle Child': 'J. Cole',
#  'Moonlight': 'XXXTentacion',
#  'Moves like Jagger': 'Maroon 5 featuring Christina Aguilera',
#  'My Blue Heaven': 'Gene Austin',
#  'My House': 'Flo Rida',
#  'My Songs Know What You Did in the Dark (Light Em Up)': 'Fall Out Boy',
#  'Need You Now': 'Lady Antebellum',
#  'Niggas in Paris': 'Jay-Z and Kanye West',
#  'No Guidance': 'Chris Brown featuring Drake',
#  'No Limit': 'G-Eazy featuring Cardi B and A$AP Rocky',
#  'No One': 'Alicia Keys',
#  'No Role Modelz': 'J. Cole',
#  'Not Afraid': 'Eminem',
#  'Old Town Road': 'Lil Nas X featuring Billy Ray Cyrus',
#  'One Dance': 'Drake featuring Wizkid and Kyla',
#  'One More Night': 'Maroon 5',
#  'Only Girl (In the World)': 'Rihanna',
#  'Paper Doll': 'Mills Brothers',
#  'Party Rock Anthem': 'LMFAO feat Lauren Bennett & GoonRock',
#  'Party in the U.S.A.': 'Miley Cyrus',
#  'Payphone': 'Maroon 5 featuring Wiz Khalifa',
#  'Perfect': 'Ed Sheeran',
#  'Poker Face': 'Lady Gaga',
#  'Pompeii': 'Bastille',
#  'Problem': 'Ariana Grande featuring Iggy Azalea',
#  'Psycho': 'Post Malone featuring Ty Dolla Sign',
#  'Pumped Up Kicks': 'Foster the People',
#  'Radioactive': 'Imagine Dragons',
#  'Ride': 'Twenty One Pilots',
#  'Right Round': 'Flo Rida featuring Kesha',
#  'Roar': 'Katy Perry',
#  'Rockstar': 'Post Malone featuring 21 Savage',
#  'Rolling in the Deep': 'Adele',
#  'Royals': 'Lorde',
#  'Rudolph, the Red-Nosed Reindeer': 'Gene Autry',
#  'Sad!': 'XXXTentacion',
#  'Sail': 'Awolnation',
#  'Say Something': 'A Great Big World and Christina Aguilera',
#  'See You Again': 'Wiz Khalifa ft. Charlie Puth',
#  'Sexy and I Know It': 'LMFAO',
#  'Shake It Off': 'Taylor Swift',
#  'Shape of You': 'Ed Sheeran',
#  'Sicko Mode': 'Travis Scott',
#  'Side to Side': 'Ariana Grande featuring Nicki Minaj',
#  'Single Ladies (Put a Ring on It)': 'Beyonce',
#  'Some Nights': 'fun.',
#  'Somebody That I Used to Know': 'Gotye featuring Kimbra',
#  'Someone Like You': 'Adele',
#  'Something Just Like This': 'The Chainsmokers and Coldplay',
#  'Sorry': 'Justin Bieber',
#  'Starboy': 'The Weeknd featuring Daft Punk',
#  'Starships': 'Nicki Minaj',
#  'Stay': 'Rihanna featuring Mikky Ekko',
#  'Stay with Me': 'Sam Smith',
#  'Stitches': 'Shawn Mendes',
#  'Stressed Out': 'Twenty One Pilots',
#  'Stronger': 'Kanye West',
#  'Sugar': 'Maroon 5',
#  'Sunflower': 'Post Malone and Swae Lee',
#  'Superbass': 'Nicki Minaj',
#  'Take Me to Church': 'Hozier',
#  'Teenage Dream': 'Katy Perry',
#  'Tennessee Whiskey': 'Chris Stapleton',
#  'That Silver-Haired Daddy Of Mine': 'Gene Autry',
#  "That's What I Like": 'Bruno Mars',
#  'The Ballad of the Green Berets': 'Barry Sadler',
#  'The Box': 'Roddy Ricch',
#  'The Hills': 'The Weeknd',
#  'The Lazy Song': 'Bruno Mars',
#  'The Monster': 'Eminem featuring Rihanna',
#  'The Tennessee Waltz': 'Patti Page',
#  'Thinking Out Loud': 'Ed Sheeran',
#  'Thrift Shop': 'Macklemore and Ryan Lewis featuring Wanz',
#  'Thriller': 'Michael Jackson',
#  'Thunder': 'Imagine Dragons',
#  'Tik Tok': 'Kesha',
#  'Timber': 'Pitbull featuring Kesha',
#  'Trap Queen': 'Fetty Wap',
#  'Turn Down for What': 'DJ Snake and Lil John',
#  'Umbrella': 'Rihanna featuring Jay-Z',
#  'Unforgettable': 'French Montana featuring Swae Lee',
#  'Uptown Funk': 'Mark Ronson featuring Bruno Mars',
#  'Viva la Vida': 'Coldplay',
#  'WAP': 'Cardi B featuring Megan Thee Stallion',
#  'Wake Me Up!': 'Avicii',
#  'Watch Me (Whip/Nae Nae)': 'Silentó',
#  'We Are Never Ever Getting Back Together': 'Taylor Swift',
#  'We Are Young': 'fun. featuring Janelle Monáe',
#  'We Are the World': 'USA for Africa',
#  'We Found Love': 'Rihanna featuring Calvin Harris',
#  'What Do You Mean?': 'Justin Bieber',
#  'When I Was Your Man': 'Bruno Mars',
#  'White Christmas': 'Bing Crosby',
#  'White Iverson': 'Post Malone',
#  'Whoomp! (There It Is)': 'Tag Team',
#  'Without Me': 'Halsey',
#  'Work': 'Rihanna',
#  'XO Tour Llif3': 'Lil Uzi Vert',
#  'You Belong with Me': 'Taylor Swift',
#  'You Light Up My Life': 'Debby Boone',
#  'Young Dumb & Broke': 'Khalid'}

# %%
# create data frame from song/artist pairs
singles_df = pd.DataFrame(singles_dict.items()) 
singles_df = singles_df.rename(columns = {0: "song", 1: "artist"})
singles_df
# Out:
#                                            song             artist
# 0                               White Christmas        Bing Crosby
# 1                       Candle in the Wind 1997         Elton John
# 2                              We Are the World     USA for Africa
# 3               Rudolph, the Red-Nosed Reindeer         Gene Autry
# 4                                    Paper Doll     Mills Brothers
# ..                                          ...                ...
# 208                                   Fuck Love       XXXTentacion
# 209                                  Better Now        Post Malone
# 210                                        Ride  Twenty One Pilots
# 211                              No Role Modelz            J. Cole
# 212  I Wanna Dance with Somebody (Who Loves Me)    Whitney Houston
#
# [213 rows x 2 columns]

# %%
# create 'api' variable that calls the AZlyrics api and Google at 50% accuracy
api = AZlyrics("google", accuracy=0.5)

# empty list for dataframe creation later
df = []

# iterate through the all artist names 
for artist in singles_df['artist'].to_list():
    api.artist = artist      # sets artist name for api call
    songs = api.getSongs()   # "getSongs()" grabs all info on all songs by artist

    # iterates through each set of song info
    for song in songs:
        # append artist, song, and album name info to "df" list
        df.append({'artist' : artist,'song' : song, 'album' : songs[song]["album"]})
        # print all info also, for sanity
        print(f'Artist: {artist}, Song: {song}, Album: {songs[song]["album"]}')

# %%
# create dataframe from "df" list
albums_df = pd.DataFrame(df)

# show dataframe
albums_df.head()

# %%
# push new dataframe to csv
albums_df.to_csv('artist_songs_albums.csv', encoding='utf-8', index=False)
